# %%
import pandas as pd
import numpy as np
import os

# %%
# Lectura de los datasets y creación de los dataframes
# csv_datasets = os.listdir('./datasets')
# for csv in csv_datasets:
#     if 'closed_deals' in csv:
#         df_closed_deals = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'customers'in csv:
#         df_customers = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'geolocation' in csv:
#         df_geolocation = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'marketing' in csv:
#         df_marketing = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'items' in csv:
#         df_items = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'payments' in csv:
#         df_order_payments = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'reviews' in csv:
#         df_order_reviews = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'created')
#     elif 'orders' in csv:
#         df_orders = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'products' in csv:
#         df_products = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'sellers' in csv:
#         df_sellers = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')
#     elif 'category' in csv:
#         df_product_category_name_translation = pd.read_csv(f'./datasets/{csv}')
#         print(csv,'dataset created')

# %%
# Lectura de los datasets y creación de los dataframes
datasets = os.listdir('./datasets')
dataframes = []
for csv in datasets:
    df = pd.read_csv(f'./datasets/{csv}')
    dataframes.append(df)

df_closed_deals = dataframes[0]
df_customers = dataframes[1]
df_geolocation = dataframes[2]
df_marketing = dataframes[3]
df_items = dataframes[4]
df_order_payments = dataframes[5]
df_order_reviews = dataframes[6]
df_orders = dataframes[7]
df_products = dataframes[8]
df_sellers = dataframes[9]
df_product_category_name_translation = dataframes[10]

# %%
#Revisión de los datasets
for number, df in enumerate(dataframes):
    print(datasets[number],':')
    print(df.isnull().sum())
# Out:
# olist_closed_deals_dataset.csv :
# mql_id                             0
# seller_id                          0
# sdr_id                             0
# sr_id                              0
# won_date                           0
# business_segment                   1
# lead_type                          6
# lead_behaviour_profile           177
# has_company                      779
# has_gtin                         778
# average_stock                    776
# business_type                     10
# declared_product_catalog_size    773
# declared_monthly_revenue           0
# dtype: int64
# olist_customers_dataset.csv :
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# olist_geolocation_dataset.csv :
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# ...

# %%
df_closed_deals
# Out:
#                                mql_id                         seller_id  \
# 0    5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1    a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2    327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3    f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4    ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
# ..                                ...                               ...
# 837  df9a2abe2ad3f2d8758b675ac8331ecf  bfcc27719640628da877db48b672b169
# 838  8723201570415eb23b4f095d8c20a27c  4a82eab98441aeb64566e2776c1fb2b6
# 839  2e57665b8faf05c967a801eb5aedfa0a  55031883943971ca22db6894574cfe2c
# 840  40955be51cc85c5a5a6cdd12b19e9f10  c0e933c238e41f0cd459d6025ee9b364
# 841  8a6492305a5fbcdcdd1a7f5a90764c07  1bba9c94eb5c4e82fba9f7286fe81025
#
#                                sdr_id                             sr_id  \
# ...
